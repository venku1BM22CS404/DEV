# %% [markdown]
# <a href="https://colab.research.google.com/github/venku1BM22CS404/DEV/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-fb4f50c2-d9b8-4849-a7b8-c8703aa4ecab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb4f50c2-d9b8-4849-a7b8-c8703aa4ecab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

ipl = pd.read_csv('ipl.csv')

# %%
df1 = ipl.notnull()
df1
# Out:
#           id  inning  over  ball  batsman  non_striker  bowler  batsman_runs  \
# 0       True    True  True  True     True         True    True          True
# 1       True    True  True  True     True         True    True          True
# 2       True    True  True  True     True         True    True          True
# 3       True    True  True  True     True         True    True          True
# 4       True    True  True  True     True         True    True          True
# ...      ...     ...   ...   ...      ...          ...     ...           ...
# 193463  True    True  True  True     True         True    True          True
# 193464  True    True  True  True     True         True    True          True
# 193465  True    True  True  True     True         True    True          True
# 193466  True    True  True  True     True         True    True          True
# 193467  True    True  True  True     True         True    True          True
#
# ...

# %%
df2 = ipl.isnull()
df2
# Out:
#            id  inning   over   ball  batsman  non_striker  bowler  \
# 0       False   False  False  False    False        False   False
# 1       False   False  False  False    False        False   False
# 2       False   False  False  False    False        False   False
# 3       False   False  False  False    False        False   False
# 4       False   False  False  False    False        False   False
# ...       ...     ...    ...    ...      ...          ...     ...
# 193463  False   False  False  False    False        False   False
# 193464  False   False  False  False    False        False   False
# 193465  False   False  False  False    False        False   False
# 193466  False   False  False  False    False        False   False
# 193467  False   False  False  False    False        False   False
#
#         batsman_runs  extra_runs  total_runs  non_boundary  is_wicket  \
# 0              False       False       False         False      False
# ...

# %%
df3 = ipl.isnull().sum()
df3
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
df4 = ipl.isnull().sum().sum()
df4
# Out:
# 738056

# %%
df5 = ipl.std()
df5
# Out:
# <ipython-input-10-870630174bac>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df5 = ipl.std()
# id              306097.091418
# inning               0.499682
# over                 5.676848
# ball                 1.807128
# batsman_runs         1.610867
# extra_runs           0.339991
# total_runs           1.598802
# non_boundary         0.009094
# is_wicket            0.216031
# dtype: float64

# %%
df6 = ipl.var()
df6
# Out:
# <ipython-input-11-15df5970eb78>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df6 = ipl.var()
# id              9.369543e+10
# inning          2.496820e-01
# over            3.222660e+01
# ball            3.265710e+00
# batsman_runs    2.594891e+00
# extra_runs      1.155941e-01
# total_runs      2.556167e+00
# non_boundary    8.269460e-05
# is_wicket       4.666949e-02
# dtype: float64

# %%
df7 = ipl.kurt()
df7
# Out:
# <ipython-input-12-116c10e2370a>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df7 = ipl.kurt()
# id                 -1.490405
# inning             -1.994905
# over               -1.183554
# ball               -1.081869
# batsman_runs        1.641151
# extra_runs         91.669822
# total_runs          1.584530
# non_boundary    12087.062490
# is_wicket          15.427817
# dtype: float64
