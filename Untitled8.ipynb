# %% [markdown]
# <a href="https://colab.research.google.com/github/venku1BM22CS404/DEV/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.DataFrame({'Scores': [78, 92, 85, 60, 75, 88, 92, 68, 72, 90, 81, 95, 79, 83, 88, 70, 64, 76, 89, 93, 87, 78, 96, 84, 71, 65, 80, 91, 77, 82]})
df
# Out:
#     Scores
# 0       78
# 1       92
# 2       85
# 3       60
# 4       75
# 5       88
# 6       92
# 7       68
# 8       72
# 9       90
# 10      81
# 11      95
# 12      79
# 13      83
# 14      88
# 15      70
# 16      64
# 17      76
# 18      89
# 19      93
# 20      87
# 21      78
# 22      96
# 23      84
# 24      71
# 25      65
# 26      80
# 27      91
# 28      77
# 29      82

# %%
df.mean()
# Out:
# Scores    80.966667
# dtype: float64

# %%
df.median()
# Out:
# Scores    81.5
# dtype: float64

# %%
df.mode()
# Out:
#    Scores
# 0      78
# 1      88
# 2      92

# %%
import numpy as np

# %%
sd = df.std()
sd
# Out:
# Scores    9.778524
# dtype: float64

# %%
v = df.var()
v
# Out:
# Scores    95.61954
# dtype: float64

# %%
df.kurt()
# Out:
# Scores   -0.690578
# dtype: float64
